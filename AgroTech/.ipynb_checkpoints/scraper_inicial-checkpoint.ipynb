# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://www.meteored.cl/tiempo-en_La+Serena-America+Sur-Chile-Coquimbo-SCSE-1-18575.html"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('td', class_='descripcion')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: Nubes y claros   Sensación T. 16°
# Encontrado: Nubes y claros   Sensación T. 17°
# Encontrado: Nubes y claros   Sensación T. 19°
# Encontrado: Nubes y claros   Sensación T. 20°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Nubes y claros   Sensación T. 22°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Nubes y claros   Sensación T. 21°
# Encontrado: Soleado   Sensación T. 20°
# Encontrado: Soleado   Sensación T. 20°
# Encontrado: Soleado   Sensación T. 19°
# Encontrado: Soleado   Sensación T. 19°
# Encontrado: Cielo despejado   Sensación T. 18°
# Encontrado: Cielo despejado   Sensación T. 17°
# Encontrado: Cielo despejado   Sensación T. 17°
# Encontrado: Cielo despejado   Sensación T. 17°
# Encontrado: Cielo despejado   Sensación T. 16°
